# %%
class Box:
    def __init__(self, length, width, height):
        self.length = length
        self.width = width
        self.height = height

    def volume(self):
        return self.length * self.width * self.height


b1 = Box(10, 5, 2)

print("Volume of the box:", b1.volume())
# Out:
# Volume of the box: 100

# %%
class Employee:
    companyName = "TechNova Pvt Ltd"   

    def __init__(self, name, age, experience, department, salary):
        self.name = name                
        self.__age = age                
        self.experience = experience     
        self.department = department     
        self.__salary = salary           

    def get_age(self):
        return self.__age

    def get_salary(self):
        return self.__salary

    def display_info(self):
        print(f"Name: {self.name}")
        print(f"Age: {self.__age}")
        print(f"Experience: {self.experience} years")
        print(f"Department: {self.department}")
        print(f"Salary: {self.__salary}")
        print(f"Company: {Employee.companyName}")


class Manager(Employee):
    def __init__(self, name, age, experience, department, salary, teams):
        super().__init__(name, age, experience, department, salary)
        self.teams = teams   

    def total_teams(self):
        return len(self.teams)

    def show_teams(self):
        print("Teams managed:", self.teams)


class Developer(Employee):
    def __init__(self, name, age, experience, department, salary, programming_language):
        super().__init__(name, age, experience, department, salary)
        self.programming_language = programming_language
 m n 
    def code(self):
        print(f"{self.name} is coding in {self.programming_language}")

    def debug(self):
        print(f"{self.name} is debugging the code")


mgr = Manager("Rahul", 35, 10, "IT", 90000, ["Backend Team", "Frontend Team"])
dev = Developer("Ankit", 25, 2, "IT", 45000, "Python")

print("\n--- Manager Info ---")
mgr.display_info()
mgr.show_teams()
print("Total teams:", mgr.total_teams())

print("\n--- Developer Info ---")
dev.display_info()
dev.code()
dev.debug()
# Out:
#   File <string>:42
#     m n
#         ^
# IndentationError: unindent does not match any outer indentation level

# %%
class TreeNode:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None


class BinaryTree:
    def __init__(self):
        self.root = None

    def add(self, value):
        new_node = TreeNode(value)

        if self.root is None:
            self.root = new_node
            return

        queue = [self.root]
        while queue:
            current = queue.pop(0)

            if current.left is None:
                current.left = new_node
                return
            else:
                queue.append(current.left)

            if current.right is None:
                current.right = new_node
                return
            else:
                queue.append(current.right)

    def count_nodes(self, node):
        if node is None:
            return 0
        return 1 + self.count_nodes(node.left) + self.count_nodes(node.right)

    def height(self, node):
        if node is None:
            return 0
        return 1 + max(self.height(node.left), self.height(node.right))

    def remove(self, value):
        if self.root is None:
            return

        if self.root.value == value and self.root.left is None and self.root.right is None:
            self.root = None
            return

        queue = [self.root]
        while queue:
            current = queue.pop(0)

            if current.left:
                if current.left.value == value:
                    current.left = None
                    return
                queue.append(current.left)

            if current.right:
                if current.right.value == value:
                    current.right = None
                    return
                queue.append(current.right)


bt = BinaryTree()
bt.add(10)
bt.add(20)
bt.add(30)
bt.add(40)
bt.add(50)

print("Total nodes:", bt.count_nodes(bt.root))
print("Height of tree:", bt.height(bt.root))

bt.remove(30)
print("After removing 30, total nodes:", bt.count_nodes(bt.root))
# Out:
# Total nodes: 5
# Height of tree: 3
# After removing 30, total nodes: 4
